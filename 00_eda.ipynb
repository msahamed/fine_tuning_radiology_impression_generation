# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./deid_reports_for_emel.csv')
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
df.shape
# Out:
# (30135, 6)

# %%
df.columns
# Out:
# Index(['report_id', 'clinic_id', 'modality', 'report_text', 'clean_report',
#        'structured_report_dict'],
#       dtype='object')

# %%
df.sample(1)
# Out:
#                                                report_id  \
# 21208  6a0718c05ae72d1f85732733c13e99c10946b48b65cb1a...
#
#                                                clinic_id modality  \
# 21208  4a7e321243420b65c96d331efc5140c52563dce27e0868...       MR
#
#                                              report_text  \
# 21208  MR ABDOMEN WITHOUT IV CONTRAST INCLUDING MRCP\...
#
#                                             clean_report  \
# 21208  MR ABDOMEN WITHOUT IV CONTRAST INCLUDING MRCP ...
#
#                                   structured_report_dict
# 21208  {('MR ABDOMEN WITHOUT IV CONTRAST INCLUDING MR...

# %%
df['clinic_id'].nunique()
# Out:
# 6

# %%
df['clinic_id'].value_counts()
# Out:
# clinic_id
# 3f2b2c77fcfb97463ccf3a792217c8cc7e420428e751b5c623ea55bebe5e33dd    10720
# f3f2ef1e-9973-4454-86ce-f9c8d19da7ef                                 8325
# bcb4bdd71a574854c688787fa8ca0dbaee668d22d3d031505725aee06fa6ec4d     3451
# 4921d977174aa6f191ef655af6918f5b028afda936aeb141a0cd9d31537f828b     3398
# 4a7e321243420b65c96d331efc5140c52563dce27e0868dc59f0f37d28c0780d     1975
# cfd6ab910cc116eaa3a8749d43f93c4c0f8f3ef345605647a8b03157fd42ec3a      865
# Name: count, dtype: int64

# %%
clinic_ids = df['clinic_id'].value_counts().index.tolist()

# %%
# clinic_ids
mapped_clinic_ids = {clinic_id: f"clinic_{idx + 1}" for idx, clinic_id in enumerate(clinic_ids)}

# %%
mapped_clinic_ids
# Out:
# {'3f2b2c77fcfb97463ccf3a792217c8cc7e420428e751b5c623ea55bebe5e33dd': 'clinic_1',
#  'f3f2ef1e-9973-4454-86ce-f9c8d19da7ef': 'clinic_2',
#  'bcb4bdd71a574854c688787fa8ca0dbaee668d22d3d031505725aee06fa6ec4d': 'clinic_3',
#  '4921d977174aa6f191ef655af6918f5b028afda936aeb141a0cd9d31537f828b': 'clinic_4',
#  '4a7e321243420b65c96d331efc5140c52563dce27e0868dc59f0f37d28c0780d': 'clinic_5',
#  'cfd6ab910cc116eaa3a8749d43f93c4c0f8f3ef345605647a8b03157fd42ec3a': 'clinic_6'}

# %%
df['mapped_clinic_id'] = df['clinic_id'].map(mapped_clinic_ids)

# %%
df['modality'].value_counts()
# Out:
# modality
# MR     18046
# CT      5322
# CR      2205
# US      2139
# XR       879
# NM       114
# PET        7
# PT         4
# IR         4
# MG         4
# FL         4
# DF         3
# DX         2
# MRA        1
# Name: count, dtype: int64

# %%
df.groupby(['mapped_clinic_id', 'modality']).size().unstack(fill_value=0)
# Out:
# modality           CR    CT  DF  DX  FL  IR  MG    MR  MRA  NM  PET  PT   US  \
# mapped_clinic_id
# clinic_1          862    33   0   0   0   0   0  9825    0   0    0   0    0
# clinic_2          822  1932   3   0   0   0   0  4860    1  11    7   0  689
# clinic_3          289   726   0   2   4   0   3  1377    0  63    0   0  987
# clinic_4            0  1701   0   0   0   0   0  1693    0   0    0   4    0
# clinic_5          232   656   0   0   0   4   1   261    0  40    0   0  411
# clinic_6            0   274   0   0   0   0   0    30    0   0    0   0   52
#
# modality           XR
# mapped_clinic_id
# clinic_1            0
# clinic_2            0
# clinic_3            0
# clinic_4            0
# clinic_5          370
# clinic_6          509

# %%
# Modality Grouping Strategy
#   Positive Effects:
#   1. Cleaner Contextualization: Model learns meaningful modality patterns rather than noise from tiny categories
#   2. Better Generalization: "OTHER" category teaches model to handle rare/unseen modalities
#   3. Reduced Overfitting: Prevents model from memorizing individual rare cases

#   Potential Concerns:
#   1. Lost Specificity: PET scans have very different language than MG, but they'd be grouped together
#   2. Edge Case Handling: Model might be less precise for truly rare modalities

# %%
#MR, CT, CR, US, XR, NM -> same name
# All others -> OTHER

modality_mapping = {mod: mod if mod in ["MR", "CT", "CR", "US", "XR", "NM"] else "OTHER" for mod in df['modality'].unique()}

# %%
modality_mapping
# Out:
# {'MR': 'MR',
#  'CT': 'CT',
#  'CR': 'CR',
#  'US': 'US',
#  'XR': 'XR',
#  'NM': 'NM',
#  'DX': 'OTHER',
#  nan: 'OTHER',
#  'PT': 'OTHER',
#  'PET': 'OTHER',
#  'IR': 'OTHER',
#  'DF': 'OTHER',
#  'MG': 'OTHER',
#  'FL': 'OTHER',
#  'MRA': 'OTHER'}

# %%
## Mapping modalities
df['mapped_modality'] = df['modality'].map(modality_mapping)

# %%
df.groupby(['mapped_clinic_id', 'mapped_modality']).size().unstack(fill_value=0)
# Out:
# mapped_modality    CR    CT    MR  NM  OTHER   US   XR
# mapped_clinic_id
# clinic_1          862    33  9825   0      0    0    0
# clinic_2          822  1932  4860  11     11  689    0
# clinic_3          289   726  1377  63      9  987    0
# clinic_4            0  1701  1693   0      4    0    0
# clinic_5          232   656   261  40      5  411  370
# clinic_6            0   274    30   0      0   52  509

# %%
from tqdm import tqdm
import pandas as pd
import ast
import json


def convert_to_json(structured_report):
    try:
        # Handle NaN or non-string inputs
        if pd.isna(structured_report) or not isinstance(structured_report, str):
            return {}

        # Parse string to dictionary
        parsed_dict = ast.literal_eval(structured_report)

        # Convert to cleaner dictionary
        clean_dict = {}
        for key_tuple, value_list in parsed_dict.items():
            # Ensure key is a tuple with one element
            if not isinstance(key_tuple, tuple) or len(key_tuple) != 1:
                continue  # Skip invalid keys
            key = key_tuple[0].rstrip(':').lower().strip()  # Clean key
            # If the list has only one item, convert to string; otherwise, keep as list
            value = value_list[0] if len(value_list) == 1 else value_list
            clean_dict[key] = value

        return clean_dict  # Return dict for efficiency
    except (SyntaxError, ValueError) as e:
        print(f"Error parsing report: {e}")
        return {}

# %%
df['report_text'].str.contains('Electronically Signed by', na=False).sum()
# Out:
# 3644

# %%
sample_data = df['structured_report_dict'].sample(1).values[0]
data = convert_to_json(sample_data)
print(list(data.keys()))
print("=========================\n")
print(f"Findings length: {len(data.get('findings', []))}, Impression length: {len(data.get('impression', []))}\n")
print("=========================\n")
print(data)
# Out:
# ['ct abdomen and pelvis without contrast, stone protocol.', 'indication', 'comparison', 'technique', 'findings', 'impression', 'no_header_53']
# =========================
#
# Findings length: 2, Impression length: 3
#
# =========================
#
# {'ct abdomen and pelvis without contrast, stone protocol.': '', 'indication': 'left flank pain, h/o kidney stones.', 'comparison': 'None.', 'technique': 'Routine CT of the abdomen and pelvis was performed without intravenous or oral contrast per renal calculus evaluation protocol. This exam is intended to evaluate for presence of renal calculi and does not adequately assess for renal or urothelial malignancies. Radiation dose reduction was utilized (automated exposure control, mA or kV adjustment based on patient size, or iterative image reconstruction). Coronal and sagittal reformatted images were generated and reviewed.', 'findings': ['Limited assessment of the abdominal organs in the absence of intravenous contrast.', ''], 'impression': ['There is a 5 mm stone in the distal left ureter causing moderate left hydronephrosis and hydroureter.', 'No bowel obstruction or wall thickening. The appendix is not identified.', 'There is no ascites or free air, abscess or adenopathy.'], 'no_header_53': 'Radiation dose reduction was utilized (automated exposure control, mA or kV adjustment based on patient size, or iterative image reconstruction).'}

# %%
# # Step 1: Get all unique keys from the dictionaries in structured_report_dict
# all_keys = set()
# for report in tqdm(df['structured_report_dict'], desc="Extracting keys"):
#     report_dict = convert_to_json(report)
#     all_keys.update(report_dict.keys())

# # Step 2: Add each key as a column, keeping lists as-is
# for key in tqdm(all_keys, desc="Creating columns"):
#     df[key] = df['structured_report_dict'].apply(
#         lambda x: convert_to_json(x).get(key, None)
#     )

# # Step 3: Split list-valued keys (e.g., IMPRESSION) into separate columns
# # Find the maximum number of items in the IMPRESSION list across all rows
# max_impressions = 0
# for report in tqdm(df['structured_report_dict'], desc="Calculating max impressions"):
#     report_dict = convert_to_json(report)
#     impression = report_dict.get('IMPRESSION', [])
#     if isinstance(impression, list):  # Ensure it's a list
#         max_impressions = max(max_impressions, len(impression))

# # Add separate columns for each IMPRESSION item
# for i in tqdm(range(max_impressions), desc="Creating IMPRESSION columns"):
#     df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
#         lambda x: convert_to_json(x).get('IMPRESSION', [])[i]
#         if isinstance(convert_to_json(x).get('IMPRESSION', []), list) and i < len(convert_to_json(x).get('IMPRESSION', []))
#         else None
#     )

# # Optionally drop the original structured_report_dict column
# # df = df.drop('structured_report_dict', axis=1)

# # Save the updated DataFrame
# df.to_csv('updated_deid_reports.csv', index=False)

# # Print updated columns
# print("Updated DataFrame columns:")
# print(df.columns)
# Out:
# Extracting keys: 100%|██████████| 30135/30135 [00:02<00:00, 12788.52it/s]
# Creating columns:   4%|▍         | 99/2456 [03:27<1:21:37,  2.08s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = df['structured_report_dict'].apply(
# Creating columns:
/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = df['structured_report_dict'].apply(
# Creating columns:   8%|▊         | 191/2456 [06:39<1:18:37,  2.08s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = df['structured_report_dict'].apply(
# Creating columns:   8%|▊         | 192/2456 [06:41<1:18:28,  2.08s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = df['structured_report_dict'].apply(
# Creating columns:   8%|▊         | 193/2456 [06:43<1:18:13,  2.07s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = df['structured_report_dict'].apply(
# Creating columns:   8%|▊         | 194/2456 [06:45<1:18:25,  2.08s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = df['structured_report_dict'].apply(
# Creating columns:   8%|▊         | 195/2456 [06:47<1:18:14,  2.08s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = df['structured_report_dict'].apply(
# Creating columns:   8%|▊         | 196/2456 [06:49<1:18:19,  2.08s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = df['structured_report_dict'].apply(
# Creating columns:   8%|▊         | 197/2456 [06:52<1:18:32,  2.09s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = df['structured_report_dict'].apply(
# Creating columns:   8%|▊         | 198/2456 [06:54<1:18:45,  2.09s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = df['structured_report_dict'].apply(
# ...
#   df[key] = df['structured_report_dict'].apply(
# Creating columns: 100%|█████████▉| 2449/2456 [2:40:02<00:14,  2.11s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = df['structured_report_dict'].apply(
# Creating columns: 100%|█████████▉| 2450/2456 [2:40:04<00:12,  2.14s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = df['structured_report_dict'].apply(
# Creating columns: 100%|█████████▉| 2451/2456 [2:40:07<00:10,  2.13s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = df['structured_report_dict'].apply(
# Creating columns: 100%|█████████▉| 2452/2456 [2:40:09<00:08,  2.14s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = df['structured_report_dict'].apply(
# Creating columns: 100%|█████████▉| 2453/2456 [2:40:11<00:06,  2.13s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = df['structured_report_dict'].apply(
# Creating columns: 100%|█████████▉| 2454/2456 [2:40:13<00:04,  2.15s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = df['structured_report_dict'].apply(
# Creating columns: 100%|█████████▉| 2455/2456 [2:40:15<00:02,  2.13s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[key] = df['structured_report_dict'].apply(
# Creating columns: 100%|██████████| 2456/2456 [2:40:17<00:00,  3.92s/it]
# Calculating max impressions: 100%|██████████| 30135/30135 [00:02<00:00, 11017.35it/s]
# Creating IMPRESSION columns:   0%|          | 0/23 [00:00<?, ?it/s]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns:   4%|▍         | 1/23 [00:05<02:08,  5.83s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns:   9%|▊         | 2/23 [00:11<02:01,  5.79s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns:  13%|█▎        | 3/23 [00:17<01:54,  5.72s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns:  17%|█▋        | 4/23 [00:22<01:44,  5.53s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns:  22%|██▏       | 5/23 [00:27<01:33,  5.21s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns:  26%|██▌       | 6/23 [00:31<01:23,  4.91s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns:  30%|███       | 7/23 [00:35<01:14,  4.68s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns:  35%|███▍      | 8/23 [00:39<01:07,  4.53s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns:  39%|███▉      | 9/23 [00:43<01:01,  4.39s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns:  43%|████▎     | 10/23 [00:47<00:55,  4.28s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns:  48%|████▊     | 11/23 [00:51<00:50,  4.20s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns:  52%|█████▏    | 12/23 [00:56<00:45,  4.16s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns:  57%|█████▋    | 13/23 [01:00<00:41,  4.14s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns:  61%|██████    | 14/23 [01:04<00:36,  4.11s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns:  65%|██████▌   | 15/23 [01:08<00:32,  4.08s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns:  70%|██████▉   | 16/23 [01:12<00:28,  4.06s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns:  74%|███████▍  | 17/23 [01:16<00:24,  4.07s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns:  78%|███████▊  | 18/23 [01:20<00:20,  4.07s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns:  83%|████████▎ | 19/23 [01:24<00:16,  4.06s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns:  87%|████████▋ | 20/23 [01:28<00:12,  4.03s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns:  91%|█████████▏| 21/23 [01:32<00:08,  4.01s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns:  96%|█████████▌| 22/23 [01:36<00:04,  4.02s/it]/var/folders/xw/88_6_hq95z5fb8b7c8xdtg7m0000gn/T/ipykernel_70384/3256823615.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'IMPRESSION_{i+1}'] = df['structured_report_dict'].apply(
# Creating IMPRESSION columns: 100%|██████████| 23/23 [01:40<00:00,  4.36s/it]
# Updated DataFrame columns:
# Index(['report_id', 'clinic_id', 'modality', 'report text', 'clean_report',
#        'structured_report_dict',
#        'ULTRASOUND ABDOMEN LIMITED RIGHT UPPER QUADRANT',
#        'Splenic coronal length', 'Origin', 'Paraspinal tissues',
#        ...
#        'IMPRESSION_14', 'IMPRESSION_15', 'IMPRESSION_16', 'IMPRESSION_17',
#        'IMPRESSION_18', 'IMPRESSION_19', 'IMPRESSION_20', 'IMPRESSION_21',
#        'IMPRESSION_22', 'IMPRESSION_23'],
#       dtype='object', length=2485)

# %%
# updated_df = pd.read_csv('updated_deid_reports.csv')

# %%
# updated_df.shape
# Out:
# (30135, 2485)
